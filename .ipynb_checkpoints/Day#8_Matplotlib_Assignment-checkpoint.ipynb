# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Q1: Create two charts using list and dataframe

# %%
#first chart
plt.subplot(1,2,1)
plt.plot([1,2,0,4,5]);
#seconf chart
plt.subplot(1,2,2)
plt.plot(pd.DataFrame([1,2,3,4,5]));

# %% [markdown]
# ## Q2: Create pie chart with equal explode values.

# %%
plt.pie(np.arange(1,5),labels=['blue','orange','green', 'red'],explode=[0.1,0.1,0.1,0.1]);
plt.title('Colors', fontsize = 20, loc='center', color='black');

# %% [markdown]
# ## Q3: Create a scatter chart with circle marker, alpha = 0.4, and size = 50.

# %%
x = np.random.randn(100)
y = np.random.randn(100)
plt.scatter(x,y, marker = 'o', alpha = 0.2, s = 50);

# %% [markdown]
# ## Q4: Add the following to your chart:
# - title placed in the left and has a red color
# - x and y label with font size = 16

# %%
plt.scatter(x,y, marker = 'o', alpha = 0.2, s = 50);
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Scatter Chart', fontsize = 16, loc='left', color='red');

# %% [markdown]
# ## Q5: Create three line charts with Legends at left and colors

# %%
plt.plot([6,2,0,4,5])
plt.plot([7,9,8,6,3])
plt.plot([4,6,7,3,2])
plt.legend(['line1','line2','line3'], shadow = True, loc = 'upper left')

# %% [markdown]
# ## Q6: Create subplots with three charts and figsize=20,10

# %%
plt.figure(figsize=[20,10])
#first
plt.subplot(1,3,1)
plt.pie(np.arange(1,5),labels=['blue','orange','green', 'red']);
plt.title('Colors', fontsize = 20, loc='center', color='black');

#second
plt.subplot(1,3,2)
plt.scatter(x,y, marker = 'o', alpha = 0.2, s = 50);

#third
plt.subplot(1,3,3)
plt.plot([1,2,0,4,5]);
