# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Q1: Create two charts using list and dataframe

# %%
x = np.array([1, 2, 3, 4, 5, 6, 7])
y = pd.DataFrame([1, 2, 3, 5, 8, 13, 20])

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Q2: Create pie chart with equal explode values.

# %%
xx = np.array([10, 10, 10, 10, 6, 10])
myexplode = np.array([0.3, 0.3, 0.3, 0.3, 0.3, 0.3])
plt.pie(xx, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# ## Q3: Create a scatter chart with circle marker, alpha = 0.4, and size = 50.

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11])
y = np.array([99,86,87,88,111,86,103,87,94,78])
plt.scatter(x, y, s = 50, alpha= 0.4)
plt.show()

# %% [markdown]
# ## Q4: Add the following to your chart:
# - title placed in the left and has a red color
# - x and y label with font size = 16

# %%
plt.title('Matplotlib Plot', c = 'red', loc='left')
x1 = np.array([5,7,8,7,2,17,2,9,4,11])
y1 = np.array([99,86,87,88,111,86,103,87,94,78])
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.scatter(x1, y1, s = 50, alpha= 0.4)
plt.show()

# %% [markdown]
# ## Q5: Create three line charts with Legends at left and colors

# %%
x = np.array([1, 2, 3, 4, 5, 6, 7])
y = np.array([1, 2, 3, 5, 8, 13, 20])
z = np.array([2, 4, 6, 8, 10, 12, 14])
plt.plot(x, linewidth = '3', markersize = 10) 
plt.plot(y, linewidth = '3', markersize = 10)
plt.plot(z, linewidth = '3', markersize = 10)
plt.legend(['x','y', 'z'], loc = 0);

plt.show()

# %% [markdown]
# ## Q6: Create subplots with three charts and figsize=20,10

# %%
plt.subplot(1, 3, 1)
plt.plot(x, linewidth = '3', markersize = 10);
plt.plot(y, linewidth = '3', markersize = 10);
plt.plot(z, linewidth = '3', markersize = 10);
plt.legend(['x','y', 'z'], loc = 0);

plt.subplot(1, 3, 2)
plt.scatter(x1, y1, s = 50, alpha= 0.4);

plt.subplot(1, 3, 3)
plt.pie(xx, explode = myexplode, shadow = True);
