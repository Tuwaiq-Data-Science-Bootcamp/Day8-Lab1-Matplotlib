# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Q1: Create two charts using list and dataframe

# %%
#using list
plt.plot([12,15,18,20,24,27,29],[10,20,40,10,20,40,49]);

# %%
#using dataframe  
plt.plot(pd.DataFrame([12,15,18,40,24,27,29]));
plt.plot(pd.DataFrame([10,20,40,10,20,40,49]));

# %% [markdown]
# ## Q2: Create pie chart with equal explode values.

# %%
#creating a pie 
x = np.arange(4)
plt.pie(x ,explode = [.1,.1,.1,.1]);

# %% [markdown]
# ## Q3: Create a scatter chart with circle marker, alpha = 0.4, and size = 50.

# %%
x = np.arange(10)
y = np.arange(10)
#using alpha for color note that alpha is from 0 to 1,using marker to change the shape, using s to chose the size
plt.scatter(x,y, alpha = 0.4, marker='o', s= 50.);

# %% [markdown]
# ## Q4: Add the following to your chart:
# - title placed in the left and has a red color
# - x and y label with font size = 16

# %%
plt.rc('xtick', labelsize=16) 
plt.rc('ytick', labelsize=16)
plt.plot(pd.DataFrame([12,15,18,40,24,27,29]));
plt.plot(pd.DataFrame([10,20,40,10,20,40,49]));
plt.xlabel( "x_l");
plt.ylabel( "y_l");
plt.title('lab1day8',loc = "left", color="red");

# %% [markdown]
# ## Q5: Create three line charts with Legends at left and colors

# %%
plt.plot([12,15,18,40,24,27,29],color = "b");
plt.plot([10,20,40,10,20,40,49],color = "green");
plt.plot([13,15,5,23,24,20,29],color = "k");
plt.legend(['1','2','3'], shadow = True, loc = "upper left");

# %% [markdown]
# ## Q6: Create subplots with three charts and figsize=20,10

# %%
plt.figure(figsize=[20,10])


#first chart
plt.subplot(1,3,1)
x = np.arange(4)
plt.pie(x ,explode = [.1,.1,.1,.1]);
#second chart
plt.subplot(1,3,2)
x = np.arange(10)
y = np.arange(10)
#using alpha for color note that alpha is from 0 to 1,using marker to change the shape, using s to chose the size
plt.scatter(x,y, alpha = 0.4, marker='o', s= 50.);
#third chart 
plt.subplot(1,3,3)
plt.plot([12,15,18,40,24,27,29],color = "b");
plt.plot([10,20,40,10,20,40,49],color = "green");
plt.plot([13,15,5,23,24,20,29],color = "k");
plt.legend(['1','2','3'], shadow = True, loc = "upper left");
