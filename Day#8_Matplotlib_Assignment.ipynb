# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Q1: Create two charts using list and dataframe

# %%
fig1 = plt.figure("Figure 1")
plt.plot([1, 3, 7, 3, 1], c="green")
plt.title("List chart")
fig2 = plt.figure("Figure 2")
plt.plot(pd.DataFrame([1, 3, 7, 3, 1]), c="red")
plt.title("Dataframe chart")
# Out:
# Text(0.5, 1.0, 'Dataframe chart')

# %% [markdown]
# ## Q2: Create pie chart with equal explode values.

# %%
plt.pie(np.arange(1,13),labels=['Jan','Feb','Mar', 'Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], explode = [2,2,2,2,2,2,2,2,2,2,2,2]);
# Out:
# c:\Users\Mo\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   func(*args, **kwargs)
# c:\Users\Mo\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Q3: Create a scatter chart with circle marker, alpha = 0.4, and size = 50.

# %%
x = np.random.randn(500);
y = np.random.randn(500);
plt.scatter(x, y,alpha=0.4,s=50);

# %% [markdown]
# ## Q4: Add the following to your chart:
# - title placed in the left and has a red color
# - x and y label with font size = 16

# %%
plt.scatter(x, y,alpha=0.4,s=50);
plt.title('Scatter figure',loc='left', color='red');

# %% [markdown]
# ## Q5: Create three line charts with Legends at left and colors

# %%
fig1 = plt.figure("Figure 1")
plt.plot([1, 3, 7, 3, 1], c="green")
plt.title("Line 1")
plt.legend(('Line1',),loc='upper left')
fig2 = plt.figure("Figure 2")
plt.plot(pd.DataFrame([1, 3, 7, 3, 1]), c="red")
plt.title("Line 2")
plt.legend(('Line2',),loc='upper left')
fig2 = plt.figure("Figure 3")
plt.plot(pd.DataFrame([1, 3, 7, 3, 1]), c="magenta")
plt.title("Line 3")
plt.legend(('Line3',),loc='upper left')

# %% [markdown]
# ## Q6: Create subplots with three charts and figsize=20,10

# %%
plt.figure(figsize=[20,10])
plt.suptitle('Subplots',fontsize = 16)

#first
plt.subplot(1,3,1)
plt.plot([1, 3, 7, 3, 1], c="green")
plt.title("Line 1")
plt.legend(('Line1',),loc='upper left')

#second
plt.subplot(1,3,2)
plt.plot(pd.DataFrame([1, 3, 7, 3, 1]), c="red")
plt.title("Line 2")
plt.legend(('Line2',),loc='upper left')

#Third
plt.subplot(1,3,3)
plt.plot(pd.DataFrame([1, 3, 7, 3, 1]), c="magenta")
plt.title("Line 3")
plt.legend(('Line3',),loc='upper left')
