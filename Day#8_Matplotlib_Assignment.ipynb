# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Q1: Create two charts using list and dataframe

# %%
plt.plot([1,2,0,4,5])
plt.plot(pd.DataFrame([9,5,3,7]));

# %% [markdown]
# ## Q2: Create pie chart with equal explode values.

# %%
plt.pie(np.arange(1,4),labels=['sara','huda','ahmad'],explode = [.1,.1,.1]);

# %% [markdown]
# ## Q3: Create a scatter chart with circle marker, alpha = 0.4, and size = 50.

# %%
x = np.random.randn(500)
y = np.random.randn(500)
plt.scatter(x, y)
plt.scatter(x, y, marker = 'o',alpha = 0.4 ,s = 50);

# %% [markdown]
# ## Q4: Add the following to your chart:
# - title placed in the left and has a red color
# - x and y label with font size = 16

# %%
x = np.random.randn(500)
y = np.random.randn(500)
plt.scatter(x, y)
plt.scatter(x, y, marker = 'o',alpha = 0.4 ,s = 50);
plt.title('title', fontsize = 16, loc='left', color='r');
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Q5: Create three line charts with Legends at left and colors

# %%
plt.plot([1,2,0,4,5], color ='g')
plt.plot([10,9,8,6,3], color ='lime')
plt.plot([12,13, 10, 20,13], color ='blue')
plt.legend(['2008','2009'], shadow = True, loc = (0.2, 0.4))

# %% [markdown]
# ## Q6: Create subplots with three charts and figsize=20,10

# %%
plt.figure(figsize=[20,10])
plt.suptitle('Subplots',fontsize = 16)


plt.subplot(1,3,1) 
plt.pie(np.arange(1,5),labels=['Jan','Feb','Mar', 'Apr']);
plt.title('Months')


plt.subplot(1,3,2)
x = np.arange(10)
y = np.arange(10)
plt.bar(x, y)
plt.xlabel('Days')
plt.ylabel('Sales')
plt.title('days');

plt.subplot(1,3,3)
plt.plot([1,2,0,4,5])
plt.plot([10,9,8,6,3])
plt.legend(['2022','2021'], shadow = True, loc = 0)
plt.title('Years')
# Out:
# Text(0.5, 1.0, 'Years')
