# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Q1: Create two charts using list and dataframe

# %%
plt.plot(pd.DataFrame([1,2,3,4]))
plt.plot([-1,-2,-3,-4]);

# %% [markdown]
# ## Q2: Create pie chart with equal explode values.

# %%
plt.pie([25,25,25,25], explode=[0.2,0.2,0.2,0.2]);

# %% [markdown]
# ## Q3: Create a scatter chart with circle marker, alpha = 0.4, and size = 50.

# %%
plt.scatter(np.random.randn(100),np.random.randn(100),alpha=0.4,s=50);

# %% [markdown]
# ## Q4: Add the following to your chart:
# - title placed in the left and has a red color
# - x and y label with font size = 16

# %%
plt.scatter(np.random.randn(100),np.random.randn(100),alpha=0.4,s=50)
plt.title('scatter',loc='left',c='r')
plt.xlabel('x Axis',fontsize=16)
plt.ylabel('y Axis',fontsize=16);

# %% [markdown]
# ## Q5: Create three line charts with Legends at left and colors

# %%
plt.plot([1,2,3,4])
plt.plot([-1,-2,-3,-4])
plt.plot([0,0,0,0]);
plt.legend('Legend',loc=0)

# %% [markdown]
# ## Q6: Create subplots with three charts and figsize=20,10

# %%
plt.figure(figsize=[20,5])
plt.suptitle('Subplots',fontsize = 16)

plt.subplot(1,3,1)
plt.plot([1,2,3,4])
plt.plot([-1,-2,-3,-4])
plt.plot([0,0,0,0]);
plt.legend('Legend',loc=0)

plt.subplot(1,3,2)
plt.scatter(np.random.randn(100),np.random.randn(100),alpha=0.4,s=50)
plt.title('scatter',loc='left',c='r')
plt.xlabel('x Axis',fontsize=16)
plt.ylabel('y Axis',fontsize=16);

plt.subplot(1,3,3)
plt.pie([25,25,25,25], explode=[0.2,0.2,0.2,0.2]);
